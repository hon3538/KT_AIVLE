# %% [markdown]
# # 서울시 공유자전거 '따릉이' 수요 예측 프로젝트
# ## 단계2. 탐색적 데이터 분석

# %% [markdown]
# ## 0.프로젝트 소개
#
# ### (1) 수행 목표
# 여러분은 서울시 정책 연구원으로써 서울시 공유자전거인 '따릉이'의 수요와 날씨간 연관성을 분석하라는 미션을 부여받았습니다.
#
# #### <font color="blue"> 데이터 분석의 주 목적은 가치있는 정보를 찾아내는것!! </font>
#
# #### 우리가 풀어야 하는 문제는 무엇인가요?
#
#  - 기상상황이 따릉이 수요에 주는 영향을 분석해봅시다.
#
#     * 1.데이터를 탐색하며 정보 획득
#         * 날씨 데이터와 서울시 공유 자전거 따릉이의 수요 데이터를 제공해드렸습니다.
#         * 우리는 따릉이의 수요와 날씨간 어떤 연관성이 있는지 탐색 해 봅시다.
#     * 2.EDA
#         * 주어진 데이터의 변수들을 분석해 봅시다.
#
#
# ### (2) 데이터 소개
#
# #### 1) 기본 데이터
#
#         * 학습데이터 : sbikedata.csv
#
# #### 2) 데이터셋의 변수 소개
#
#         * date : 날짜
#         * hour : 시간
#         * temperature : 온도
#         * precipitation : 강우 여부, 비가 오지 않았으면 0, 비가 오면 1
#         * windspeed : 풍속(평균)
#         * humidity : 습도
#         * visibility : 시정(視程), 시계(視界)(특정 기상 상태에 따른 가시성을 의미)
#         * ozone : 오존 수치
#         * PM10 : 미세먼지 수치(머리카락 굵기의 1/5에서 1/7 크기의 미세먼지)
#         * PM2.5 : 초미세먼지 수치(머리카락 굵기의 1/20에서 1/30 크기의 미세먼지)
#         * count : 시간에 따른 따릉이 대여 수

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정
#         * 로컬 수행(Ananconda)
#             * 제공된 압축파일을 다운받아 압축을 풀고
#             * anaconda의 root directory(보통 C:/Users/< ID > 에 project 폴더를 만들고, 복사해 넣습니다.
#
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정 및 라이브러리 로딩
# * 이번 프로젝트는 로컬환경에서 진행합니다.

# %% [markdown]
# #### 1) 로컬 수행(Anaconda)
# * project 폴더에 필요한 파일들을 넣고, 본 파일을 열었다면, 별도 경로 지정이 필요하지 않습니다.

# %%
# path = 'C:/Users/User/'

# %% [markdown]
# #### 2) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.graphics.mosaicplot import mosaic
from scipy import stats as spst
import statsmodels.api as sm
import joblib

# 더 필요한 라이브러리를 아래에 추가합니다.

# %% [markdown]
# ### (2) 데이터 불러오기
# * 주어진 데이터셋
#     * 따릉이 수요 및 날씨 데이터 : sbikedata.csv

# %% [markdown]
# #### 1) 데이터로딩

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df = pd.read_csv('./ddarueng.csv')

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
#전체 데이터의 행,열 개수 확인

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
#전체 데이터의 모든 변수 확인

# %% [markdown]
# ## 2.EDA 2단계 - 가설 설정
#
# *  '가설' 이란 단어를 생각해보면, 우리가 직접 가설을 만들어야 할것 같지만 통계에서 분석기법별 귀무가설/대립가설은 정해져있습니다.
# - 귀무가설은 차이가 없다, 연관성이 없다, 효과가 없다.
# - 대립가설은 차이가 있다, 연관성이 있다, 효과가 있다. 라고 간단하게 이해하시면 좋습니다.
#
#     * 간단한 예로, 온도와 따릉이 대여량간 가설을 수립 해본다면
#
#         - 귀무가설 : 온도와 따릉이 간에는 연관성이 없다.
#         - 대립가설 : 온도와 따릉이 간에는 연관성이 있다.
#
#         로 가설이 자연스레 수립 됩니다.

# %% [markdown]
# ### (1) 가설 수립
# * 'precipitation' 변수를 포함하여, 최소 5개 이상의 Feature와 따릉이 대여량 간 가설을 수립해주세요.
#     * Guide : Target은 따릉이 대여량 입니다.

# %% [markdown]
# * 귀무가설 1: 온도와 따릉이 대여량간에는 관계가 없다.
# * 대립가설 1: 온도와 따릉이 대여량간에는 관계가 있다.
#
#
# * 귀무가설 2:
# * 대립가설 2: 온도에 따라 따릉이 대여수에 영향이 있을 것이다
#
#
# * 귀무가설 3:
# * 대립가설 3: 공기질에 따라 따릉이 대여수에 영향이 있을 것이다
#
#
# * 귀무가설 4:
# * 대립가설 4: 요일 별로 따릉이 대여수에 영향이 있을 것이다
#
#
# * 귀무가설 5:
# * 대립가설 5: 강우 여부에 따라 따릉이 대여수에 영향이 있을 것이다.

# %% [markdown]
# ## 3.EDA 3단계 - 이변량 분석
# * 자료의 종류에 맞게 X --> Y 에 대해서 그래프(시각화)와 가설검정(수치화)를 수행하고 결과를 평가합니다.
# * 가설검정시 다음의 항목을 참조하여 수행합니다.
#     * 유의수준 : 5%
#     * 숫자 --> 숫자 : 상관분석
#     * 범주 --> 범주 : 카이제곱검정
#     * 범주 --> 숫자 : t검정, 분산분석
#     * 숫자 --> 범주 : 로지스틱 회귀모형을 통해, 회귀계수의 P.value로 검정을 수행합니다.

# %% [markdown]
# ### (1) 범주형 Feature --> 숫자형 Y (따릉이 대여 Count)
# * 모든 범주형 Feature에 대해서 Y와 비교하여 차트를 그리고 수치화 하시오.
#     1. 시각화 : 그래프를 활용한 데이터 분석
#     2. 수치화 : t-test, anova
#     3. 관계 평가

# %% [markdown]
# #### 1) 강수 여부와 따릉이 대여량간 이변량 분석

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# 1시간 전 비가 오지 않았을떄 (0 일때) 따릉이 대여 건수 평균이 100이상임
#
# 1시간 전 비가 왔을때 (1 일때) 따릉이 대여 건수는 매우 낮은 편임

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# * 귀무가설은 X가 Y와 관련이 없다.
# * 대립가설은 X와 Y가 관련이 있다.
#
# * P-value (유의확률)가 0.05 이하라면? 해당 변수는 매우 유의미한 값으로 판단 가능함

# %% [markdown]
# ### (2) 숫자형 Feature --> 숫자형 Y (따릉이 대여 Count)
# * 모든 숫자형 Feature에 대해서 Y와 비교하여 차트를 그리고 수치화 하시오.
#     1. 시각화 : 그래프를 활용한 데이터 분석
#     2. 수치화 : 상관분석
#     3. 관계 평가

# %% [markdown]
# #### 1) 시간대별 대여량 분석

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
temp = df.groupby('hour', as_index=False)['count'].sum()
temp.columns = ['hour','count']
sns.barplot(x='hour', y='count', data= temp)
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### 2) 온도 데이터 분석

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
temp = df.groupby('temperature', as_index=False)['count'].sum()
temp.columns = ['temperature','count']
sns.histplot(x='temperature', y='count', data= temp, bins=30)
# Out:
# <Axes: xlabel='temperature', ylabel='count'>

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### 3) 풍속에 대한 분석

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### 4) 습도에 대한 예측

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### 5) 시정에 대한 분석

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### 6) 오존 데이터 분석

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### 7) 미세먼지 농도 데이터 분석

# %%
# 단변량 분석
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(x= 'PM10', data=df, bins=20, kde=True)
plt.grid()

plt.subplot(1,2,2)
sns.histplot(x= 'PM2.5', data=df, bins=20, kde=True)
plt.grid()
plt.show()

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.scatterplot(x='PM10', y='count', data=df)
plt.grid()

plt.subplot(1,2,2)
sns.scatterplot(x='PM2.5', y='count', data=df)
plt.grid()
plt.show()
import scipy.stats as spst
print(spst.pearsonr(df['PM10'], df['count'])) # PM10
print(spst.pearsonr(df['PM2.5'], df['count'])) # PM2.5
# Out:
# PearsonRResult(statistic=0.02731694538877957, pvalue=0.037199903057257115)
# PearsonRResult(statistic=0.0343752151505596, pvalue=0.008736181684750441)

# %%
# .pearson corr
import scipy.stats as spst
print(spst.pearsonr(df['PM10'], df['count'])) # PM10
print(spst.pearsonr(df['PM2.5'], df['count'])) # PM2.5
# Out:
# PearsonRResult(statistic=0.02731694538877957, pvalue=0.037199903057257115)
# PearsonRResult(statistic=0.0343752151505596, pvalue=0.008736181684750441)

# %%
df.head(1)
# Out:
#    Unnamed: 0        date  hour  PM10  PM2.5  ozone  temperature  \
# 0           0  2021-04-01     1  42.0   21.0  0.002         13.1
#
#    precipitation  windspeed  humidity  visibility  count 공기질 PM10_c
# 0              0        1.4        49        2000     46  보통   good

# %%
# 비오는날은  미세먼지가 적다, 맑은 날 기준
temp = df.loc[df['precipitation']==0,:]
sns.scatterplot(x='PM10', y='count', data=temp)
plt.grid()
plt.show()

# %%
# 100 기준범주형으로변환
df['PM10_c'] = pd.Series(['good' if i<100 else 'bad'  for i in df['PM10']])

# %%
sns.barplot(x='PM10_c', y='count', data=df)
# Out:
# <Axes: xlabel='PM10_c', ylabel='count'>

# %%
temp = df.loc[df['PM10_c']=='good', :]
sns.scatterplot(x='PM10',y='count', data=temp)
spst.pearsonr(temp['PM10'],temp['count'])
# sns.scatterplot(x='요일', y='PM10', data=temp)
# Out:
# PearsonRResult(statistic=0.06696591684863806, pvalue=6.295138481379597e-05)

# %%
# 좋은 것들 안에서 count와 hour 관계
sns.barplot(x='PM10', y='count', data=temp)
# 23~7 는 거의 없는 것으로 보임
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
# 주요 시간대만 분석
condition = (df['hour'] >= 8)&(df['hour'] <=22)
df = df.loc[condition,  :]

# 공기질 -> 대여량
sns.barplot(x='공기질', y='count', data=df)
# Out:
# <Axes: xlabel='공기질', ylabel='count'>

# %%
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
# 주말과 평일으로 나눠보자
# datetime.workday() 월 0 일 6
df['date'] = pd.to_datetime(df['date'])
df['요일'] = df['date'].dt.weekday.map({0:'평일',1:'평일',2:'평일',3:'평일',4:'평일',5:'주말',6:'주말'})

# %%
df.groupby('요일')[]

# %%
# 공기질 (PM10 + PM2.5)
sns.barplot(x='공기질', y ='count', data=df)
plt.show()
df.loc[df['공기질']=='매우나쁨','count'].mean()
# Out:
# 208.20833333333334

# %%
pd.crosstab(df['요일'],df['공기질'])
mosaic(df, ['요일','공기질'])
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  {('평일', '보통'): (0.0, 0.0, 0.7077024639607054, 0.37948212414281557),
#   ('평일', '좋음'): (0.0,
#    0.38278245417581885,
#    0.7077024639607054,
#    0.5869291617416939),
#   ('평일', '나쁨'): (0.0,
#    0.973011945950516,
#    0.7077024639607054,
#    0.017227435648349818),
#   ('평일', '매우나쁨'): (0.0,
#    0.9935397116318689,
#    0.7077024639607054,
#    0.006460288368131127),
#   ('주말', '보통'): (0.7126775883388148,
#    0.0,
#    0.28732241166118533,
#    0.3135313531353135),
#   ('주말', '좋음'): (0.7126775883388148,
#    0.31683168316831684,
#    0.28732241166118533,
#    0.6194012258368694),
#   ('주말', '나쁨'): (0.7126775883388148,
#    0.9395332390381895,
#    0.28732241166118533,
#    0.030645921735030647),
#   ('주말', '매우나쁨'): (0.7126775883388148,
#    0.9734794908062234,
#    0.28732241166118533,
#    0.026520509193776538)})

# %%
# PM10 과 PM2.5 상관성
sns.scatterplot(x='PM2.5', y='PM10', data= df)
plt.show()
spst.pearsonr(df['PM10'], df['PM2.5'])
# Out:
# PearsonRResult(statistic=0.6842653956697496, pvalue=0.0)

# %%
# 비율이 다른 두가지 상관성이 보임, 비율로 계산
temp = df.loc[df[]]
# Out:
# count    5818.000000
# mean        2.414572
# std         1.538139
# min         0.818182
# 25%         1.608696
# 50%         1.952381
# 75%         2.600000
# max        22.000000
# dtype: float64

# %% [markdown]
# #### 8) 초미세먼지 농도에 대한 분석

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# ## 4. 가설 검정

# %% [markdown]
# ### 1. 강한 관계의 변수 (대립가설 채택)

# %% [markdown]
# ### 2. 약한 관계의 변수

# %% [markdown]
# ### 3. 관계 없는 변수 (귀무가설 채택)

# %% [markdown]
# ## 5. Insight 도출
