# %% [markdown]
# # 이진분류 종합실습 : 이직 예측

# %% [markdown]
# * 회사 인사팀에서는 AIVLER 들에게 직원의 이직여부과 관련해서 분석을 요청하였습니다.
# * 최근 이직율이 증가하는 것에 대해 우려를 갖고 있기에, 이직여부에 영향을 주는 요인에 대해 분석하여, 이직할 것으로 보이는 직원들에 대해 회사를 떠나지 않도록 인사 프로그램을 준비하려고 합니다.
# * 어떤 직원이 이직할지 예측해 봅시다.

# %% [markdown]
# ![](https://adoptostaging.blob.core.windows.net/media/employee-attrition-reasons-9LIqMv.jpg)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터 로딩

# %%
# data data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_train_validation.CSV"
data = pd.read_csv(path)
data['Attrition'] = np.where(data['Attrition']=='Yes', 1, 0)
data.head(10)
# Out:
#    Attrition  Age     BusinessTravel              Department  \
# 0          0   33      Travel_Rarely  Research & Development
# 1          0   35  Travel_Frequently  Research & Development
# 2          0   42      Travel_Rarely  Research & Development
# 3          0   46      Travel_Rarely                   Sales
# 4          0   39  Travel_Frequently                   Sales
# 5          1   22  Travel_Frequently  Research & Development
# 6          0   24      Travel_Rarely  Research & Development
# 7          0   34      Travel_Rarely  Research & Development
# 8          0   30      Travel_Rarely  Research & Development
# 9          0   26      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeNumber  \
# 0                 7          3           Medical             817
# 1                18          2     Life Sciences            1412
# 2                 6          3           Medical            1911
# 3                 2          3         Marketing            1204
# 4                20          3     Life Sciences            1812
# 5                 4          1  Technical Degree             593
# 6                21          2  Technical Degree            1551
# 7                 8          3           Medical            2068
# 8                20          3             Other            1084
# 9                 6          3     Life Sciences             686
#
#    EnvironmentSatisfaction  Gender  ...  OverTime PercentSalaryHike  \
# 0                        3    Male  ...        No                11
# 1                        3    Male  ...        No                11
# 2                        3    Male  ...        No                13
# 3                        3  Female  ...        No                23
# 4                        3    Male  ...        No                18
# 5                        3    Male  ...        No                16
# 6                        3    Male  ...        No                14
# 7                        2    Male  ...        No                12
# 8                        3    Male  ...        No                15
# 9                        3  Female  ...       Yes                13
#
#    RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# 0                         4                0                 14
# 1                         3                0                 10
# 2                         2                1                 18
# 3                         1                0                 28
# 4                         4                1                  7
# 5                         3                0                  4
# 6                         2                3                  2
# 7                         1                0                  6
# 8                         3                1                  7
# 9                         3                1                  3
#
#    TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      3               4              13                   9
# 1                      2               3               2                   2
# 2                      3               4              13                   7
# 3                      2               3              26                  15
# 4                      6               3               2                   1
# 5                      3               3               2                   2
# 6                      3               3               1                   1
# 7                      3               4               4                   3
# 8                      1               2               6                   2
# 9                      2               3               3                   2
#
#    YearsWithCurrManager
# 0                     7
# 1                     2
# 2                     7
# 3                     9
# 4                     2
# 5                     2
# 6                     0
# 7                     2
# 8                     2
# 9                     2
#
# [10 rows x 26 columns]

# %% [markdown]
# |	변수 명	|	내용	|	구분	|
# |	----	|	----	|	----	|
# |	**Attrition**	|	이직여부, Yes = 1 , No = 0	|	**Target**	|
# |	Age	|	나이	|	숫자	|
# |	BusinessTravel	|	출장 빈도(범주)	|		|
# |	Department	|	현 부서	|		|
# |	DistanceFromHome	|	집-직장 거리(마일)	|	숫자	|
# |	Education	|	교육수준(범주)	|	1 Below College, 2 College, 3 Bachelor, 4 Master, 5 Doctor	|
# |	EducationField	|	전공	|		|
# |	EmployeeNumber	|	사번	|		|
# |	EnvironmentSatisfaction	|	근무환경에 대한 만족도(범주)	|	1 Low, 2 Good, 3 Excellent, 4 Outstanding	|
# |	Gender	|	성별	|		|
# |	JobInvolvement	|	직무 적극성(참여도)	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	JobRole	|	직무	|		|
# |	JobSatisfaction	|	직무 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	MaritalStatus	|	결혼상태	| Single, Married, Divorced		|
# |	MonthlyIncome	|	월급	|	숫자	|
# |	NumCompaniesWorked	|	현재까지 근무한 회사 수	|	숫자	|
# |	OverTime	|	야근여부	|	범주	|
# |	PercentSalaryHike	|	전년대비 급여인상율(%)	|	숫자	|
# |	RelationshipSatisfaction	|	동료와의 관계 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	StockOptionLevel	|	스톡옵션 수준 0~3	|	범주	|
# |	TotalWorkingYears	|	총 근무 연수	|	숫자	|
# |	TrainingTimesLastYear	|	전년 교육훈련 횟수	|	숫자	|
# |	WorkLifeBalance	|	워라밸. 일-삶 균형도	|	1 Bad, 2 Good, 3 Better, 4 Best	|
# |	YearsAtCompany	|	현직장 근무 연수	|	숫자	|
# |	YearsInCurrentRole	|	현직무 연수	|	숫자	|
# |	YearsWithCurrManager	|	현 팀장과 근무한 연수	|	숫자	|

# %% [markdown]
# ----

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# ### (1) 데이터 정리

# %%
target = 'Attrition'

# %%
# 불필요한 변수 제거
data.drop('EmployeeNumber', axis = 1, inplace = True)

# %%
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화
# * 범주형 데이터이면서 값이 0,1 로 되어 있는 것이 아니라면, 가변수화를 수행해야 합니다.
# * 대상이 되는 변수에 대해서 가변수화를 수행해주세요.

# %%
dum_cols = ['BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction','Gender',
            'JobRole', 'JobInvolvement', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'RelationshipSatisfaction',
            'StockOptionLevel','WorkLifeBalance' ]

x = pd.get_dummies(x, columns = dum_cols ,drop_first = True)
x.head()
# Out:
#    Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# 0   33                 7          11691                   0
# 1   35                18           9362                   2
# 2   42                 6          13348                   9
# 3   46                 2          17048                   8
# 4   39                20           4127                   2
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11                 14                      3
# 1                 11                 10                      2
# 2                 13                 18                      3
# 3                 23                 28                      2
# 4                 18                  7                      6
#
#    YearsAtCompany  YearsInCurrentRole  YearsWithCurrManager  ...  \
# 0              13                   9                     7  ...
# 1               2                   2                     2  ...
# 2              13                   7                     7  ...
# 3              26                  15                     9  ...
# 4               2                   1                     2  ...
#
#    OverTime_Yes  RelationshipSatisfaction_2  RelationshipSatisfaction_3  \
# 0             0                           0                           0
# 1             0                           0                           1
# 2             0                           1                           0
# 3             0                           0                           0
# 4             0                           0                           0
#
#    RelationshipSatisfaction_4  StockOptionLevel_1  StockOptionLevel_2  \
# 0                           1                   0                   0
# 1                           0                   0                   0
# 2                           0                   1                   0
# 3                           0                   0                   0
# 4                           1                   1                   0
#
#    StockOptionLevel_3  WorkLifeBalance_2  WorkLifeBalance_3  WorkLifeBalance_4
# 0                   0                  0                  0                  1
# 1                   0                  0                  1                  0
# 2                   0                  0                  0                  1
# 3                   0                  0                  1                  0
# 4                   0                  0                  1                  0
#
# [5 rows x 53 columns]

# %% [markdown]
# ### (3) 데이터 분할
# * train_test_split :
#     * test_size : 0.# - 비율로 분할, 1보다 큰 자연수 - 갯수로 분할
#     * train_size로 지정도 가능.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 200, random_state = 2022)

# %% [markdown]
# ### (4) 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 4.모델링

# %% [markdown]
# ### (1) 모델1
# * 다양한 구조의 모델 2개 이상을 설계하시오. (히든레이어, 노드 수 조절)

# %%
clear_session()
model = Sequential( [Dense(30, input_shape=(x_train.shape[1],), activation='relu'),
                     Dense(15, activation='relu'),
                     Dense(1, activation='sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                1620
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 2101 (8.21 KB)
# Trainable params: 2101 (8.21 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy')

# %%
history = model.fit(x_train,  y_train, epochs=50, validation_split=.2, verbose = 0).history

# %%
dl_history_plot(history)

# %%
y_pred = model.predict(x_val)
y_pred = np.where(y_pred > 0.5, 1, 0)
print(classification_report(y_val, y_pred))
# Out:
# 7/7 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       169
#            1       0.52      0.48      0.50        31
#
#     accuracy                           0.85       200
#    macro avg       0.71      0.70      0.71       200
# weighted avg       0.85      0.85      0.85       200

# %% [markdown]
# ### (1) 모델2
# * 다양한 구조의 모델 2개 이상을 설계하시오. (히든레이어, 노드 수 조절)

# %%
clear_session()
model = Sequential( [Dense(30, input_shape=(x_train.shape[1],), activation='relu'),
                     Dense(15, activation='relu'),
                     Dense(5, activation='relu'),
                     Dense(1, activation='sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                1620
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 5)                 80
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 2171 (8.48 KB)
# Trainable params: 2171 (8.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
history = model.fit(x_train,  y_train, epochs=50, validation_split=.2).history
dl_history_plot(history)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 9ms/step - loss: 0.5196 - val_loss: 0.4235
# Epoch 2/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4431 - val_loss: 0.3969
# Epoch 3/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4253 - val_loss: 0.3893
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4088 - val_loss: 0.3815
# Epoch 5/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3979 - val_loss: 0.3746
# Epoch 6/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3861 - val_loss: 0.3675
# Epoch 7/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3712 - val_loss: 0.3585
# Epoch 8/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3510 - val_loss: 0.3505
# Epoch 9/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3324 - val_loss: 0.3473
# Epoch 10/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3137 - val_loss: 0.3465
# Epoch 11/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2997 - val_loss: 0.3417
# Epoch 12/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2890 - val_loss: 0.3445
# Epoch 13/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2768 - val_loss: 0.3433
# Epoch 14/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2669 - val_loss: 0.3479
# Epoch 15/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2551 - val_loss: 0.3387
# Epoch 16/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2464 - val_loss: 0.3577
# Epoch 17/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2387 - val_loss: 0.3696
# Epoch 18/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2323 - val_loss: 0.3608
# Epoch 19/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2195 - val_loss: 0.3669
# Epoch 20/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2115 - val_loss: 0.3613
# Epoch 21/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2031 - val_loss: 0.3543
# Epoch 22/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1983 - val_loss: 0.3521
# Epoch 23/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1925 - val_loss: 0.3858
# Epoch 24/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1833 - val_loss: 0.3704
# Epoch 25/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1731 - val_loss: 0.3853
# Epoch 26/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1666 - val_loss: 0.4028
# Epoch 27/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1580 - val_loss: 0.4130
# Epoch 28/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1512 - val_loss: 0.4198
# Epoch 29/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1424 - val_loss: 0.4139
# Epoch 30/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1376 - val_loss: 0.4352
# Epoch 31/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1313 - val_loss: 0.4575
# Epoch 32/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1285 - val_loss: 0.4704
# Epoch 33/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1167 - val_loss: 0.4867
# Epoch 34/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1109 - val_loss: 0.5151
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1027 - val_loss: 0.4819
# Epoch 36/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0968 - val_loss: 0.5462
# Epoch 37/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0961 - val_loss: 0.6229
# Epoch 38/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0964 - val_loss: 0.5291
# Epoch 39/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0857 - val_loss: 0.5417
# Epoch 40/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0801 - val_loss: 0.5595
# Epoch 41/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0750 - val_loss: 0.5799
# Epoch 42/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.5774
# Epoch 43/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0676 - val_loss: 0.5849
# Epoch 44/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0630 - val_loss: 0.5824
# Epoch 45/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0595 - val_loss: 0.6057
# Epoch 46/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0556 - val_loss: 0.6271
# Epoch 47/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.6082
# Epoch 48/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0507 - val_loss: 0.7003
# Epoch 49/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0527 - val_loss: 0.6889
# Epoch 50/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0414 - val_loss: 0.6874

# %%
y_pred = model.predict(x_val)
y_pred = np.where(y_pred > 0.5, 1, 0)

print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# 7/7 [==============================] - 0s 4ms/step
# [[160   9]
#  [ 16  15]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       169
#            1       0.62      0.48      0.55        31
#
#     accuracy                           0.88       200
#    macro avg       0.77      0.72      0.74       200
# weighted avg       0.87      0.88      0.87       200

# %% [markdown]
# ### (2) 모델2 : resampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
print(x_train.shape, y_train.shape)
print(y_train.value_counts())
# Out:
# (1050, 53) (1050,)
# 0    881
# 1    169
# Name: Attrition, dtype: int64

# %%
ros = RandomOverSampler()
x_train_ros, y_train_ros = ros.fit_resample(x_train, y_train)
print(x_train_ros.shape, y_train_ros.shape) # 클래스 1 의 데이터 건수가 881-169 개 만큼 over sampling 된다.
# Out:
# (1762, 53) (1762,)

# %%
model2.compile(  )
hist = model2.fit( x_train_ros, y_train_ros,  ,  ).history
