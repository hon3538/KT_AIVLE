# %% [markdown]
# # Classification : 2 Class

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 함수

# %%
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.3.csv"
data = pd.read_csv(path)
data.drop(['Age_scale1', 'AgeGroup', 'SibSp','Parch' ], axis = 1, inplace = True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Family
# 0         0       3    male  22.0   7.2500        S       2
# 1         1       1  female  38.0  71.2833        C       2
# 2         1       3  female  26.0   7.9250        S       1
# 3         1       1  female  35.0  53.1000        S       2
# 4         0       3    male  35.0   8.0500        S       1

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# Sex, Age, Fare 만 이용하여 Survived 를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ### (1) 데이터 준비

# %%
target = 'Survived'
features = ['Sex', 'Age', 'Fare']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화

# %%
x = pd.get_dummies(x, columns = ['Sex'], drop_first = True)
x.head()
# Out:
#     Age     Fare  Sex_male
# 0  22.0   7.2500         1
# 1  38.0  71.2833         0
# 2  26.0   7.9250         0
# 3  35.0  53.1000         0
# 4  35.0   8.0500         1

# %% [markdown]
# ### (3) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1: 3개 feature

# %% [markdown]
# ### (1) 모델설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 모델 만들기
model = Sequential( Dense( 1 , input_shape = (nfeatures ,), activation= 'sigmoid') )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4 (16.00 Byte)
# Trainable params: 4 (16.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer = Adam(learning_rate=0.01), loss = 'binary_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 16ms/step - loss: 0.6800 - val_loss: 0.6456
# Epoch 2/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6367 - val_loss: 0.6093
# Epoch 3/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6141 - val_loss: 0.5911
# Epoch 4/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6016 - val_loss: 0.5801
# Epoch 5/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5925 - val_loss: 0.5705
# Epoch 6/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5845 - val_loss: 0.5623
# Epoch 7/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5770 - val_loss: 0.5550
# Epoch 8/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5705 - val_loss: 0.5489
# Epoch 9/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5635 - val_loss: 0.5423
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5583 - val_loss: 0.5366
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5527 - val_loss: 0.5309
# Epoch 12/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5475 - val_loss: 0.5269
# Epoch 13/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5443 - val_loss: 0.5242
# Epoch 14/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5390 - val_loss: 0.5193
# Epoch 15/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5361 - val_loss: 0.5153
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5323 - val_loss: 0.5122
# Epoch 17/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5293 - val_loss: 0.5101
# Epoch 18/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5267 - val_loss: 0.5073
# Epoch 19/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5241 - val_loss: 0.5053
# Epoch 20/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5219 - val_loss: 0.5034
# Epoch 21/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5198 - val_loss: 0.5015
# Epoch 22/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5181 - val_loss: 0.4996
# Epoch 23/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5164 - val_loss: 0.4983
# Epoch 24/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5147 - val_loss: 0.4972
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5133 - val_loss: 0.4956
# Epoch 26/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5122 - val_loss: 0.4950
# Epoch 27/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5116 - val_loss: 0.4934
# Epoch 28/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5099 - val_loss: 0.4928
# Epoch 29/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5089 - val_loss: 0.4926
# Epoch 30/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5078 - val_loss: 0.4916
# Epoch 31/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5071 - val_loss: 0.4904
# Epoch 32/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5061 - val_loss: 0.4906
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5053 - val_loss: 0.4898
# Epoch 34/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5046 - val_loss: 0.4901
# Epoch 35/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5040 - val_loss: 0.4890
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5034 - val_loss: 0.4882
# Epoch 37/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5028 - val_loss: 0.4882
# Epoch 38/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5023 - val_loss: 0.4880
# Epoch 39/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5018 - val_loss: 0.4871
# Epoch 40/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5015 - val_loss: 0.4875
# Epoch 41/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5007 - val_loss: 0.4868
# Epoch 42/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5002 - val_loss: 0.4870
# Epoch 43/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4997 - val_loss: 0.4865
# Epoch 44/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4993 - val_loss: 0.4860
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4988 - val_loss: 0.4861
# Epoch 46/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4987 - val_loss: 0.4858
# Epoch 47/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4980 - val_loss: 0.4861
# Epoch 48/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4978 - val_loss: 0.4857
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4974 - val_loss: 0.4857
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4973 - val_loss: 0.4861

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred = model.predict(x_val)

# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred = np.where(pred >= .5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
print(classification_report(y_val, pred))

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 준비

# %%
target = 'Survived'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# * 가변수화

# %%
cat_cols = ['Pclass','Sex', 'Embarked']
x = pd.get_dummies(x, columns = cat_cols, drop_first = True)

# %% [markdown]
# * 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
# 메모리 정리
clear_session()

# Sequential 모델
model =  Sequential( Dense( 1, activation = 'sigmoid', input_shape=(x_train.shape[1], )))

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.05), loss='binary_crossentropy')
model.fit(x_train, y_train, epochs=30, validation_split=.2)
# Out:
# Epoch 1/30
# 16/16 [==============================] - 1s 20ms/step - loss: 0.5721 - val_loss: 0.5166
# Epoch 2/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5129 - val_loss: 0.4798
# Epoch 3/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4963 - val_loss: 0.4657
# Epoch 4/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4838 - val_loss: 0.4632
# Epoch 5/30
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4761 - val_loss: 0.4577
# Epoch 6/30
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4700 - val_loss: 0.4513
# Epoch 7/30
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4690 - val_loss: 0.4483
# Epoch 8/30
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4624 - val_loss: 0.4497
# Epoch 9/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4610 - val_loss: 0.4463
# Epoch 10/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4587 - val_loss: 0.4447
# Epoch 11/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4571 - val_loss: 0.4464
# Epoch 12/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4532 - val_loss: 0.4441
# Epoch 13/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4542 - val_loss: 0.4420
# Epoch 14/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4512 - val_loss: 0.4411
# Epoch 15/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4491 - val_loss: 0.4440
# Epoch 16/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4474 - val_loss: 0.4410
# Epoch 17/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4459 - val_loss: 0.4404
# Epoch 18/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4444 - val_loss: 0.4419
# Epoch 19/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4424 - val_loss: 0.4406
# Epoch 20/30
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4431 - val_loss: 0.4434
# Epoch 21/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4423 - val_loss: 0.4399
# Epoch 22/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4404 - val_loss: 0.4418
# Epoch 23/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4409 - val_loss: 0.4403
# Epoch 24/30
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4396 - val_loss: 0.4407
# Epoch 25/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4406 - val_loss: 0.4401
# Epoch 26/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4375 - val_loss: 0.4396
# Epoch 27/30
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4389 - val_loss: 0.4403
# Epoch 28/30
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4370 - val_loss: 0.4415
# Epoch 29/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4403 - val_loss: 0.4437
# Epoch 30/30
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4384 - val_loss: 0.4402

# %% [markdown]
# * 학습결과 그래프

# %% [markdown]
# * 예측 및 검증

# %%
pred = model.predict(x_val)

# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred = np.where(pred >= .5, 1, 0)
print(classification_report(y_val, pred))
# Out:
# 9/9 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83       170
#            1       0.71      0.66      0.68        98
#
#     accuracy                           0.78       268
#    macro avg       0.76      0.75      0.76       268
# weighted avg       0.77      0.78      0.77       268

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 모델 설계

# %%
n = x_train.shape[1]
n
# Out:
# 8

# %%
# 메모리 정리
clear_session()

# Sequential 모델
model3 = Sequential([ Dense( 4, input_shape = (n ,), activation = 'relu'),
                      Dense( 1, activation = 'sigmoid')])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 36
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 41 (164.00 Byte)
# Trainable params: 41 (164.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model3.compile( optimizer=Adam(learning_rate= 0.01), loss ='binary_crossentropy')
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=.2 ).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 14ms/step - loss: 0.6098 - val_loss: 0.5662
# Epoch 2/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5798 - val_loss: 0.5471
# Epoch 3/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5570 - val_loss: 0.5295
# Epoch 4/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5362 - val_loss: 0.5119
# Epoch 5/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5189 - val_loss: 0.5021
# Epoch 6/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5020 - val_loss: 0.4900
# Epoch 7/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4885 - val_loss: 0.4789
# Epoch 8/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4782 - val_loss: 0.4711
# Epoch 9/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4691 - val_loss: 0.4653
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4616 - val_loss: 0.4646
# Epoch 11/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4572 - val_loss: 0.4600
# Epoch 12/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4512 - val_loss: 0.4588
# Epoch 13/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4454 - val_loss: 0.4569
# Epoch 14/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4433 - val_loss: 0.4560
# Epoch 15/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4390 - val_loss: 0.4534
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4356 - val_loss: 0.4540
# Epoch 17/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4351 - val_loss: 0.4508
# Epoch 18/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4357 - val_loss: 0.4516
# Epoch 19/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4333 - val_loss: 0.4493
# Epoch 20/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4267 - val_loss: 0.4496
# Epoch 21/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4231 - val_loss: 0.4463
# Epoch 22/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4202 - val_loss: 0.4420
# Epoch 23/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4174 - val_loss: 0.4443
# Epoch 24/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4151 - val_loss: 0.4404
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4131 - val_loss: 0.4396
# Epoch 26/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4108 - val_loss: 0.4370
# Epoch 27/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4093 - val_loss: 0.4359
# Epoch 28/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4079 - val_loss: 0.4305
# Epoch 29/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4060 - val_loss: 0.4343
# Epoch 30/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4028 - val_loss: 0.4295
# Epoch 31/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4022 - val_loss: 0.4310
# Epoch 32/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3997 - val_loss: 0.4325
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3990 - val_loss: 0.4277
# Epoch 34/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4026 - val_loss: 0.4286
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3981 - val_loss: 0.4295
# Epoch 36/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3968 - val_loss: 0.4276
# Epoch 37/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3938 - val_loss: 0.4317
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3943 - val_loss: 0.4260
# Epoch 39/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3963 - val_loss: 0.4319
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3916 - val_loss: 0.4278
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3922 - val_loss: 0.4272
# Epoch 42/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3889 - val_loss: 0.4245
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3901 - val_loss: 0.4268
# Epoch 44/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3900 - val_loss: 0.4242
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3928 - val_loss: 0.4248
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3885 - val_loss: 0.4288
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3950 - val_loss: 0.4209
# Epoch 48/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3899 - val_loss: 0.4247
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3849 - val_loss: 0.4226
# Epoch 50/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3902 - val_loss: 0.4226

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(hist)

# %% [markdown]
# * 예측 및 검증

# %%
pred3 = model3.predict(x_val)
pred3 = np.where(pred3 >= 0.5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       170
#            1       0.76      0.65      0.70        98
#
#     accuracy                           0.80       268
#    macro avg       0.79      0.77      0.78       268
# weighted avg       0.80      0.80      0.79       268

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | 옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16)  | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 1) | node, activation = 'sigmoid' |

# %%
clear_session()
model = Sequential( [Dense(16, input_shape=(x_train.shape[1],), activation='relu'),
                     Dense(1, activation='sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 161 (644.00 Byte)
# Trainable params: 161 (644.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.03), loss='binary_crossentropy')

# %%
history = model.fit(x_train, y_train, epochs=30, validation_split=0.2, verbose=0).history

# %%
dl_history_plot(history)

# %%
y_pred = model.predict(x_val)
y_pred = np.where(y_pred > 0.5, 1, 0)
print(classification_report(y_val, y_pred))
# Out:
# 9/9 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.85       170
#            1       0.81      0.55      0.65        98
#
#     accuracy                           0.79       268
#    macro avg       0.79      0.74      0.75       268
# weighted avg       0.79      0.79      0.78       268

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape |  옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16) |  node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 8) |  node, activation = 'relu'  |
# | dense_2 (Dense) | (None, 1) |  node, activation = 'sigmoid'  |

# %%
clear_session()
model = Sequential([Dense(16, input_shape=(x_train.shape[1],), activation='relu'),
                    Dense(8, activation='relu'),
                    Dense(1, activation='sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 289 (1.13 KB)
# Trainable params: 289 (1.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy')
history = model.fit(x_train, y_train, epochs=30, validation_split=.2, verbose=0).history

# %%
dl_history_plot(history)

# %%
y_pred = model.predict(x_val)
y_pred = np.where(y_pred > 0.5, 1, 0)
print(classification_report(y_val, y_pred))
# Out:
# 9/9 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       170
#            1       0.75      0.64      0.69        98
#
#     accuracy                           0.79       268
#    macro avg       0.78      0.76      0.77       268
# weighted avg       0.79      0.79      0.79       268

# %% [markdown]
# ### (5) 실습3

# %% [markdown]
# * 이번에는 여러분이 원하는 대로 설계하고, 학습해 봅시다.
